# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# ML--> knn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler ,LabelEncoder

# %%
df = pd.read_csv('C:/Users/pinki/OneDrive/Desktop/Data_science(infosis)/datascience/data/student.csv')

# %%
df.shape
# Out:
# (395, 33)

# %%
df
# Out:
#     school sex  age address famsize Pstatus                           Medu  \
# 0       GP   F   18       U     GT3       A               higher education
# 1       GP   F   17       U     GT3       T  primary education (4th grade)
# 2       GP   F   15       U     LE3       T  primary education (4th grade)
# 3       GP   F   15       U     GT3       T               higher education
# 4       GP   F   16       U     GT3       T            secondary education
# ..     ...  ..  ...     ...     ...     ...                            ...
# 390     MS   M   20       U     LE3       A               5th to 9th grade
# 391     MS   M   17       U     LE3       T            secondary education
# 392     MS   M   21       R     GT3       T  primary education (4th grade)
# 393     MS   M   18       R     LE3       T            secondary education
# 394     MS   M   19       U     LE3       T  primary education (4th grade)
#
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df_sample = df[['Medu', 'Fedu','traveltime', 'studytime', 'failures', 'schoolsup', 'famsup',
    'activities','internet','famrel', 'freetime', 'goout', 'Dalc','Walc', 
    'health', 'absences', 'G1', 'G2', 'G3']]

# %%
df = df_sample

# %%
df.shape
# Out:
# (395, 19)

# %%
columnsdf = ['Medu', 'Fedu', 'traveltime', 'studytime','schoolsup',
       'famsup', 'activities', 'internet', 'famrel', 'freetime', 'goout',
       'Dalc', 'Walc', 'health']

# %%
for col in columnsdf:
    print(col)
    print('-'*50)
    unique =  df[col].unique()
    print(unique)
    print('-'*50)
# Out:
# Medu
# --------------------------------------------------
# ['higher education' 'primary education (4th grade)' 'secondary education'
#  '5th to 9th grade' 'none']
# --------------------------------------------------
# Fedu
# --------------------------------------------------
# ['higher education' 'primary education (4th grade)' '5th to 9th grade'
#  'secondary education' 'none']
# --------------------------------------------------
# traveltime
# --------------------------------------------------
# ['15 to 30 min.' '<15 min.' '30 min. to 1 hour' '>1 hour']
# --------------------------------------------------
# studytime
# --------------------------------------------------
# ['2 to 5 hours' '5 to 10 hours' '<2 hours' '>10 hours']
# --------------------------------------------------
# schoolsup
# --------------------------------------------------
# ['yes' 'no']
# --------------------------------------------------
# famsup
# --------------------------------------------------
# ...

# %%
edu = {
'none':0,
'primary education (4th grade)': 1,
'secondary education':2,
'higher education':3,
'5th to 9th grade' :4
}
columns = ['Medu','Fedu']
for col in columns:
 df[col] = df[col].map(edu)
# Out:
# C:\Users\pinki\AppData\Local\Temp\ipykernel_11084\4213046110.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(edu)
# C:\Users\pinki\AppData\Local\Temp\ipykernel_11084\4213046110.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(edu)

# %%
df.shape
# Out:
# (395, 19)

# %%
sf ={
    "yes" :1,
    "no" : 0
}

column =['schoolsup','famsup']
for col in column:
    df[col] = df[col].map(sf)
# Out:
# C:\Users\pinki\AppData\Local\Temp\ipykernel_11084\750724910.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sf)
# C:\Users\pinki\AppData\Local\Temp\ipykernel_11084\750724910.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].map(sf)

# %%
df
# Out:
#      Medu  Fedu         traveltime      studytime  failures  schoolsup  \
# 0       3     3      15 to 30 min.   2 to 5 hours         0        NaN
# 1       1     1           <15 min.   2 to 5 hours         0        NaN
# 2       1     1           <15 min.   2 to 5 hours         3        NaN
# 3       3     4           <15 min.  5 to 10 hours         0        NaN
# 4       2     2           <15 min.   2 to 5 hours         0        NaN
# ..    ...   ...                ...            ...       ...        ...
# 390     4     4           <15 min.   2 to 5 hours         2        NaN
# 391     2     1      15 to 30 min.       <2 hours         0        NaN
# 392     1     1           <15 min.       <2 hours         3        NaN
# 393     2     4  30 min. to 1 hour       <2 hours         0        NaN
# 394     1     1           <15 min.       <2 hours         0        NaN
#
#      famsup activities internet     famrel   freetime      goout      Dalc  \
# ...

# %%
df['health'].unique()
# Out:
# array(['good', 'excellent', 'very bad', 'bad', 'very good'], dtype=object)

# %%
hlth = {
    0:'very good',
    1:'bad',
    2 :'good',
    3 :'very good',
    4:'excellent'
}
df['health'] = df['health'].map(hlth)
# Out:
# C:\Users\pinki\AppData\Local\Temp\ipykernel_11084\3710690070.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['health'] = df['health'].map(hlth)

# %%
df
# Out:
#      Medu  Fedu         traveltime      studytime  failures  schoolsup  \
# 0       3     3      15 to 30 min.   2 to 5 hours         0          1
# 1       1     1           <15 min.   2 to 5 hours         0          0
# 2       1     1           <15 min.   2 to 5 hours         3          1
# 3       3     4           <15 min.  5 to 10 hours         0          0
# 4       2     2           <15 min.   2 to 5 hours         0          0
# ..    ...   ...                ...            ...       ...        ...
# 390     4     4           <15 min.   2 to 5 hours         2          0
# 391     2     1      15 to 30 min.       <2 hours         0          0
# 392     1     1           <15 min.       <2 hours         3          0
# 393     2     4  30 min. to 1 hour       <2 hours         0          0
# 394     1     1           <15 min.       <2 hours         0          0
#
#      famsup activities internet     famrel   freetime      goout      Dalc  \
# ...
